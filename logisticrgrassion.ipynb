# %%
# maling data in excel formate for testing lgistic regration
# steps will be genrate randome data of diffirent ages and there eligibility to apply for loan in tow collumns age 
# and eligibility status 

import pandas as pd
import random
import numpy as np


age = []
eligibility = []

for i in range(100):
  age.append(random.randint(20, 60))

for i in range(100):
  eligibility.append(random.choice([0, 1]))

df = pd.DataFrame({'age': age, 'eligibility': eligibility})

df
# Out:
# C:\Users\ASR\AppData\Local\Temp\ipykernel_16076\2961671064.py:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#     age  eligibility
# 0    33            0
# 1    59            0
# 2    48            1
# 3    55            1
# 4    51            0
# ..  ...          ...
# 95   49            1
# 96   45            1
# 97   32            0
# 98   51            0
# 99   24            0
#
# [100 rows x 2 columns]

# %%
df.head(20).to_excel('data.xlsx')

# %%
df.to_csv('data.csv')

# %%
import matplotlib.pyplot as plt

# %%
dataset = df.head(20)
dataset
# Out:
#     age  eligibility
# 0    33            0
# 1    59            0
# 2    48            1
# 3    55            1
# 4    51            0
# 5    21            0
# 6    36            0
# 7    43            0
# 8    60            1
# 9    34            0
# 10   40            1
# 11   55            0
# 12   36            1
# 13   26            1
# 14   27            1
# 15   32            0
# 16   54            0
# 17   49            0
# 18   57            1
# 19   44            0

# %%
age = np.array([21,45,32,41,20,35,20,23,42,34,24,22,23,25,43,44,25,30,31])
inssurance = np.array(['no', 'yes', 'yes', 'yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'no', 'no', 'yes', 'yes', 'no', 'yes', 'yes'])

df = pd.DataFrame({'age': age, 'inssurance': inssurance})
df
# Out:
#     age inssurance
# 0    21         no
# 1    45        yes
# 2    32        yes
# 3    41        yes
# 4    20         no
# 5    35        yes
# 6    20         no
# 7    23         no
# 8    42        yes
# 9    34        yes
# 10   24         no
# 11   22         no
# 12   23         no
# 13   25         no
# 14   43        yes
# 15   44        yes
# 16   25         no
# 17   30        yes
# 18   31        yes

# %%
#convert all yes to 1 and all no to 0
datafinal = df.replace({'inssurance': {'yes': 1, 'no': 0}})
datafinal
# Out:
# C:\Users\ASR\AppData\Local\Temp\ipykernel_16076\3631666158.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   datafinal = df.replace({'inssurance': {'yes': 1, 'no': 0}})
#     age  inssurance
# 0    21           0
# 1    45           1
# 2    32           1
# 3    41           1
# 4    20           0
# 5    35           1
# 6    20           0
# 7    23           0
# 8    42           1
# 9    34           1
# 10   24           0
# 11   22           0
# 12   23           0
# 13   25           0
# 14   43           1
# 15   44           1
# 16   25           0
# 17   30           1
# 18   31           1

# %%
df
# Out:
#     age  inssurance
# 0    21           0
# 1    45           1
# 2    32           1
# 3    41           1
# 4    20           0
# 5    35           1
# 6    20           0
# 7    23           0
# 8    42           1
# 9    34           1
# 10   24           0
# 11   22           0
# 12   23           0
# 13   25           0
# 14   43           1
# 15   44           1
# 16   25           0
# 17   30           1
# 18   31           1

# %%
df['inssurance'].replace({'yes': 1, 'no': 0}, inplace = True)
df
# Out:
# C:\Users\ASR\AppData\Local\Temp\ipykernel_16076\3040447370.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df['inssurance'].replace({'yes': 1, 'no': 0}, inplace = True)
#     age  inssurance
# 0    21           0
# 1    45           1
# 2    32           1
# 3    41           1
# 4    20           0
# 5    35           1
# 6    20           0
# 7    23           0
# 8    42           1
# 9    34           1
# 10   24           0
# 11   22           0
# 12   23           0
# 13   25           0
# 14   43           1
# 15   44           1
# 16   25           0
# 17   30           1
# 18   31           1

# %%
plt.scatter(x=df['age'], y=df['inssurance'], color = 'red')

# %%
plt.scatter(x='age', y='inssurance', color = 'red', data=df)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(df[['age']], df.inssurance, test_size=0.2, random_state=0)

X_train
# Out:
#     age
# 14   43
# 16   25
# 6    20
# 4    20
# 2    32
# 5    35
# 13   25
# 9    34
# 7    23
# 17   30
# 11   22
# 3    41
# 0    21
# 15   44
# 12   23
