# %%
# maling data in excel formate for testing lgistic regration
# steps will be genrate randome data of diffirent ages and there eligibility to apply for loan in tow collumns age 
# and eligibility status 

import pandas as pd
import random
import numpy as np


age = []
eligibility = []

for i in range(100):
  age.append(random.randint(20, 60))

for i in range(100):
  eligibility.append(random.choice([0, 1]))

df = pd.DataFrame({'age': age, 'eligibility': eligibility})

df
# Out:
# C:\Users\ASR\AppData\Local\Temp\ipykernel_2916\2961671064.py:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#     age  eligibility
# 0    50            0
# 1    46            1
# 2    58            1
# 3    38            0
# 4    31            0
# ..  ...          ...
# 95   37            1
# 96   40            1
# 97   25            0
# 98   49            1
# 99   22            0
#
# [100 rows x 2 columns]

# %%
df.head(20).to_excel('data.xlsx')

# %%
df.to_csv('data.csv')

# %%
import matplotlib.pyplot as plt

# %%
dataset = df.head(20)
dataset
# Out:
#     age  eligibility
# 0    50            0
# 1    46            1
# 2    58            1
# 3    38            0
# 4    31            0
# 5    52            0
# 6    27            0
# 7    44            0
# 8    39            1
# 9    25            1
# 10   59            1
# 11   24            1
# 12   50            0
# 13   36            0
# 14   50            0
# 15   58            1
# 16   39            1
# 17   56            0
# 18   23            0
# 19   51            1

# %%
age = np.array([21,45,32,41,20,35,20,23,42,34,24,22,23,25,43,44,25,30,31])
inssurance = np.array(['no', 'yes', 'yes', 'yes', 'no', 'yes', 'no', 'no', 'yes', 'yes', 'no', 'no', 'no', 'no', 'yes', 'yes', 'no', 'yes', 'yes'])

df = pd.DataFrame({'age': age, 'inssurance': inssurance})
df.to_excel('data.xlsx')

# %%
#convert all yes to 1 and all no to 0
datafinal = df.replace({'inssurance': {'yes': 1, 'no': 0}})
datafinal
# Out:
# C:\Users\ASR\AppData\Local\Temp\ipykernel_2916\3631666158.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   datafinal = df.replace({'inssurance': {'yes': 1, 'no': 0}})
#     age  inssurance
# 0    21           0
# 1    45           1
# 2    32           1
# 3    41           1
# 4    20           0
# 5    35           1
# 6    20           0
# 7    23           0
# 8    42           1
# 9    34           1
# 10   24           0
# 11   22           0
# 12   23           0
# 13   25           0
# 14   43           1
# 15   44           1
# 16   25           0
# 17   30           1
# 18   31           1

# %%
df.to_excel('data.xlsx')

# %%
df['inssurance'].replace({'yes': 1, 'no': 0}, inplace = True)
df
# Out:
# C:\Users\ASR\AppData\Local\Temp\ipykernel_2916\3040447370.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['inssurance'].replace({'yes': 1, 'no': 0}, inplace = True)
# C:\Users\ASR\AppData\Local\Temp\ipykernel_2916\3040447370.py:1: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
plt.scatter(x=df['age'], y=df['inssurance'], color = 'red')

# %%
plt.scatter(x='age', y='inssurance', color = 'red', data=df)

# %%
from sklearn.model_selection import train_test_split

# %%
#extracting data from excel file and saving it in a csv file.
exceldata = pd.read_excel('data.xlsx', index_col=0)
exceldata.to_csv('data.csv')

# %%
csvdata = pd.read_csv('data.csv', index_col=0)
csvdata["inssurance"].replace({'yes': 1, 'no': 0}, inplace=True)
csvdata
# Out:
# C:\Users\ASR\AppData\Local\Temp\ipykernel_2916\377112176.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   csvdata["inssurance"].replace({'yes': 1, 'no': 0}, inplace=True)
# C:\Users\ASR\AppData\Local\Temp\ipykernel_2916\377112176.py:2: FutureWarning: Downcasting behavior in `replace` is deprecated and will be removed in a future version. To retain the old behavior, explicitly call `result.infer_objects(copy=False)`. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
# ...

# %%
plt.scatter(x='age', y='inssurance', color = 'g', data=csvdata)

# %%
x_train, x_test, y_train, y_test = train_test_split(csvdata[['age']], csvdata['inssurance'], test_size=0.2, random_state=42) # 80% training and 20% test

# %%
len(x_test)
len(x_test)
# Out:
# 4

# %%
x_test
# Out:
#     age
# 0    21
# 5    35
# 11   22
# 1    45

# %%
from sklearn.linear_model import LogisticRegression
model = LogisticRegression()
model.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
model.predict(x_test)
# Out:
# array([0, 1, 0, 1], dtype=int64)

# %%
model.predict([[27]])
# Out:
# c:\Users\ASR\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([0], dtype=int64)

# %%
model.predict([[28]])
# Out:
# c:\Users\ASR\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# array([1], dtype=int64)

# %%
#confussion matrix
model.score(x_test, y_test)
# Out:
# 1.0
